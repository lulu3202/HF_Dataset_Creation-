# %%
# Import necessary libraries
import pandas as pd
from googletrans import Translator

# %%
# Step 1: Load the CSV file into a pandas DataFrame
df = pd.read_csv('Thirukural_EnglishMeaning.csv')

# Check the first few rows to ensure it's loaded properly
df.head()
# Out:
#        ChapterName                                              Kural  \
# 0  கடவுள் வாழ்த்து      அகர முதல எழுத்தெல்லாம் ஆதி பகவன் முதற்றே உலகு
# 1  கடவுள் வாழ்த்து  கற்றதனால் ஆய பயனென்கொல் வாலறிவன் நற்றாள் தொழாஅ...
# 2  கடவுள் வாழ்த்து  மலர்மிசை ஏகினான் மாணடி சேர்ந்தார் நிலமிசை நீடு...
# 3  கடவுள் வாழ்த்து  வேண்டுதல் வேண்டாமை இலானடி சேர்ந்தார்க்கு யாண்ட...
# 4  கடவுள் வாழ்த்து  இருள்சேர் இருவினையும் சேரா இறைவன் பொருள்சேர் ப...
#
#                                       EnglishMeaning
# 0  A is the first of the alphabet; God is the pri...
# 1  What is the use of all your learning, if you c...
# 2  Those who surrender themselves at feet of the ...
# 3  Those who surrender at the feet of the one, wh...
# 4  Fate, which impacts those in the darkness of i...

# %%
# Step 1.1: Rename the columns
df.rename(columns={
    'Kural': 'Tamil_Kural',  # Rename 'Kural' to 'Tamil_Kural'
    'EnglishMeaning': 'English_Meaning',  # Rename 'EnglishMeaning' to 'English_Meaning'
    'ChapterName': 'Tamil_Category'  # Rename 'ChapterName' to 'Tamil_Category'
}, inplace=True)

# Check the first few rows to ensure it's loaded properly
df.head()
# Out:
#     Tamil_Category                                        Tamil_Kural  \
# 0  கடவுள் வாழ்த்து      அகர முதல எழுத்தெல்லாம் ஆதி பகவன் முதற்றே உலகு
# 1  கடவுள் வாழ்த்து  கற்றதனால் ஆய பயனென்கொல் வாலறிவன் நற்றாள் தொழாஅ...
# 2  கடவுள் வாழ்த்து  மலர்மிசை ஏகினான் மாணடி சேர்ந்தார் நிலமிசை நீடு...
# 3  கடவுள் வாழ்த்து  வேண்டுதல் வேண்டாமை இலானடி சேர்ந்தார்க்கு யாண்ட...
# 4  கடவுள் வாழ்த்து  இருள்சேர் இருவினையும் சேரா இறைவன் பொருள்சேர் ப...
#
#                                      English_Meaning
# 0  A is the first of the alphabet; God is the pri...
# 1  What is the use of all your learning, if you c...
# 2  Those who surrender themselves at feet of the ...
# 3  Those who surrender at the feet of the one, wh...
# 4  Fate, which impacts those in the darkness of i...

# %%
# Step 2: Initialize the Google Translator
translator = Translator()

# %%
# Step 3: Define a function to translate Tamil text to English
def translate_text(text):
    try:
        # Translate text from Tamil to English
        translation = translator.translate(text, src='ta', dest='en')
        return translation.text
    except Exception as e:
        return str(e)  # Return the error if any

# %%
# Step 4: Apply the translation function to the 'Tamil_Category' column
df['English_Category'] = df['Tamil_Category'].apply(translate_text)

# %%
# Step 5: View the updated DataFrame
df.head()
# Out:
#     Tamil_Category                                        Tamil_Kural  \
# 0  கடவுள் வாழ்த்து      அகர முதல எழுத்தெல்லாம் ஆதி பகவன் முதற்றே உலகு
# 1  கடவுள் வாழ்த்து  கற்றதனால் ஆய பயனென்கொல் வாலறிவன் நற்றாள் தொழாஅ...
# 2  கடவுள் வாழ்த்து  மலர்மிசை ஏகினான் மாணடி சேர்ந்தார் நிலமிசை நீடு...
# 3  கடவுள் வாழ்த்து  வேண்டுதல் வேண்டாமை இலானடி சேர்ந்தார்க்கு யாண்ட...
# 4  கடவுள் வாழ்த்து  இருள்சேர் இருவினையும் சேரா இறைவன் பொருள்சேர் ப...
#
#                                      English_Meaning  English_Category
# 0  A is the first of the alphabet; God is the pri...  Greetings of God
# 1  What is the use of all your learning, if you c...  Greetings of God
# 2  Those who surrender themselves at feet of the ...  Greetings of God
# 3  Those who surrender at the feet of the one, wh...  Greetings of God
# 4  Fate, which impacts those in the darkness of i...  Greetings of God

# %%
# Step 5.1 Validate the translation provided by the Google translate service
# Display unique entries in Tamil_Category and English_Category
unique_categories = df[['Tamil_Category', 'English_Category']].drop_duplicates()
pd.set_option('display.max_rows', None)  # This ensures all rows are displayed
print(unique_categories)

#spoiler alert - translation is bad as this is ancient Tamil - I went the manual labelling route for this
# Out:
#               Tamil_Category  \
# 0            கடவுள் வாழ்த்து
# 10               வான்சிறப்பு
# 20           நீத்தார் பெருமை
# 30         அறன் வலியுறுத்தல்
# 31         அறன் வலியுறுத்தல்
# 40               இல்வாழ்க்கை
# 50       வாழ்க்கைத் துணைநலம்
# 60        புதல்வரைப் பெறுதல்
# 70                 அன்புடைமை
# 80             விருந்தோம்பல்
# 90               இனியவைகூறல்
# 100       செய்ந்நன்றி அறிதல்
# 101       செய்ந்நன்றி அறிதல்
# 110             நடுவு நிலைமை
# 120              அடக்கமுடைமை
# 130             ஒழுக்கமுடைமை
# 140         பிறனில் விழையாமை
# 150               பொறையுடைமை
# 160              அழுக்காறாமை
# 170                  வெஃகாமை
# 180              புறங்கூறாமை
# 190           பயனில சொல்லாமை
# 200             தீவினையச்சம்
# 210             ஒப்புரவறிதல்
# 220                      ஈகை
# 222                      ஈகை
# 230                    புகழ்
# 240                அருளுடைமை
# 250           புலான்மறுத்தல்
# 260                     தவம்
# 270            கூடாவொழுக்கம்
# 271            கூடாவொழுக்கம்
# 280                  கள்ளாமை
# 290                   வாய்மை
# 300                 வெகுளாமை
# 301                 வெகுளாமை
# 310            இன்னாசெய்யாமை
# 320                 கொல்லாமை
# 330                 நிலையாமை
# 340                    துறவு
# 350             மெய்யுணர்தல்
# 360              அவாவறுத்தல்
# 370                      ஊழ்
# 380                இறைமாட்சி
# 390                    கல்வி
# 400                  கல்லாமை
# 410                   கேள்வி
# 420                அறிவுடைமை
# 430            குற்றங்கடிதல்
# 440   பெரியாரைத் துணைக்கோடல்
# 442   பெரியாரைத் துணைக்கோடல்
# 450          சிற்றினஞ்சேராமை
# 460         தெரிந்துசெயல்வகை
# 470                வலியறிதல்
# 480                காலமறிதல்
# 490                 இடனறிதல்
# 500          தெரிந்துதெளிதல்
# 510        தெரிந்துவினையாடல்
# 520             சுற்றந்தழால்
# 530               பொச்சாவாமை
# 540               செங்கோன்மை
# 550             கொடுங்கோன்மை
# 560         வெருவந்தசெய்யாமை
# 563         வெருவந்தசெய்யாமை
# 570               கண்ணோட்டம்
# 580                 ஒற்றாடல்
# 590               ஊக்கமுடைமை
# 600                மடியின்மை
# 610            ஆள்வினையுடைமை
# 620            இடுக்கணழியாமை
# 630                  அமைச்சு
# 640                சொல்வன்மை
# 650             வினைத்தூய்மை
# 660            வினைத்திட்பம்
# 670             வினைசெயல்வகை
# 680                     தூது
# 690   மன்னரைச் சேர்ந்தொழுதல்
# 700             குறிப்பறிதல்
# 710                அவையறிதல்
# 720               அவையஞ்சாமை
# 730                     நாடு
# 740                     அரண்
# 750           பொருள்செயல்வகை
# 751           பொருள்செயல்வகை
# 760                படைமாட்சி
# 762                படைமாட்சி
# 770            படைச்செருக்கு
# 780                    நட்பு
# 790             நட்பாராய்தல்
# 800                    பழைமை
# 801                    பழைமை
# 810                 தீ நட்பு
# 820                கூடாநட்பு
# 830                   பேதைமை
# 831                   பேதைமை
# 840            புல்லறிவாண்மை
# 850                     இகல்
# 860                பகைமாட்சி
# 870        பகைத்திறந்தெரிதல்
# 880                   உட்பகை
# 890      பெரியாரைப் பிழையாமை
# 900           பெண்வழிச்சேறல்
# 910            வரைவின்மகளிர்
# 920              கள்ளுண்ணாமை
# 930                     சூது
# 936                     சூது
# 940                  மருந்து
# 945                  மருந்து
# 950                   குடிமை
# 960                    மானம்
# 970                   பெருமை
# 976                   பெருமை
# 980               சான்றாண்மை
# 981               சான்றாண்மை
# 990                பண்புடைமை
# 1000        நன்றியில்செல்வம்
# 1001        நன்றியில்செல்வம்
# 1010                நாணுடைமை
# 1011                நாணுடைமை
# 1018                நாணுடைமை
# 1020            குடிசெயல்வகை
# 1030                    உழவு
# 1040                நல்குரவு
# 1050                    இரவு
# 1060                இரவச்சம்
# 1070                    கயமை
# 1073                    கயமை
# 1080        தகையணங்குறுத்தல்
# 1082        தகையணங்குறுத்தல்
# 1100       புணர்ச்சிமகிழ்தல்
# 1110     நலம்புனைந்துரைத்தல்
# 1120     காதற்சிறப்புரைத்தல்
# 1122     காதற்சிறப்புரைத்தல்
# 1130      நாணுத்துறவுரைத்தல்
# 1140          அலரறிவுறுத்தல்
# 1150            பிரிவாற்றாமை
# 1160      படர்மெலிந்திரங்கல்
# 1167      படர்மெலிந்திரங்கல்
# 1170         கண்விதுப்பழிதல்
# 1180         பசப்புறுபருவரல்
# 1182         பசப்புறுபருவரல்
# 1186         பசப்புறுபருவரல்
# 1190         தனிப்படர்மிகுதி
# 1193         தனிப்படர்மிகுதி
# 1200      நினைந்தவர்புலம்பல்
# 1201      நினைந்தவர்புலம்பல்
# 1210       கனவுநிலையுரைத்தல்
# 1211       கனவுநிலையுரைத்தல்
# 1220       பொழுதுகண்டிரங்கல்
# 1221       பொழுதுகண்டிரங்கல்
# 1230         உறுப்புநலனழிதல்
# 1234         உறுப்புநலனழிதல்
# 1240        நெஞ்சொடுகிளத்தல்
# 1241        நெஞ்சொடுகிளத்தல்
# 1250              நிறையழிதல்
# 1251              நிறையழிதல்
# 1260      அவர்வயின்விதும்பல்
# 1265      அவர்வயின்விதும்பல்
# 1270      குறிப்பறிவுறுத்தல்
# 1280      புணர்ச்சிவிதும்பல்
# 1290        நெஞ்சொடுபுலத்தல்
# 1291        நெஞ்சொடுபுலத்தல்
# 1300                   புலவி
# 1310         புலவி நுணுக்கம்
# 1320                 ஊடலுவகை
# 1321                 ஊடலுவகை
# 1324                 ஊடலுவகை
#
#                                        English_Category
# 0                                      Greetings of God
# 10                                            Aerospace
# 20                                         Neetar proud
# 30                                            Credering
# 31                                              Charity
# 40                                             Erythema
# 50                                               Viagal
# 60                                             Souvenir
# 70                                               Loving
# 80                                          Hospitality
# 90                                            Off swing
# 100                                            Chopping
# 101                                         Chickenness
# 110                                             Midmary
# 120                                      Impressiveness
# 130                                          Immorality
# 140                                       Incorporation
# 150                                           Endurance
# 160                                              Agenia
# 170                                             Aimatum
# 180                                          Infidelity
# 190                                        Inexperience
# 200                                               Incom
# 210                                              Agrees
# 220                                             Stature
# 222                                             Dictate
# 230                                              Praise
# 240                                               Grace
# 250                                         Quarterment
# 260                                             Penance
# 270                                        Idase stress
# 271                                        Idane stress
# 280                                             Inertia
# 290                                               Vowel
# 300                                          Population
# 301                                           Viagation
# 310                           Innayyyyyyyyyyyyyyyyyyyyy
# 320                                               Kolam
# 330                                           Inontated
# 340                                                Rent
# 350                                          Conspiracy
# 360                                      Demanding call
# 370                                                Blow
# 380                                                Lord
# 390                                           Education
# 400                                            Illusion
# 410                                            Question
# 420                                           Discovery
# 430                                               Blade
# 440                                           Eastodoat
# 442                                         Eakse botls
# 450                                            Chrinnum
# 460                                           Awareness
# 470                                          Affiration
# 480                                          Chronology
# 490                                           Interrupt
# 500                                           Ascending
# 510                                         Implication
# 520                                               Peril
# 530                                            Downside
# 540                                              Source
# 550                                             Tyranny
# 560                                                Amem
# 563                                              Akorus
# 570                                            Overview
# 580                                                 Odd
# 590                                           Incentive
# 600                                         Implication
# 610                                         Lawlessness
# 620                                          Incubation
# 630                                            Ministry
# 640                                            Emphasis
# 650                                            Catalyst
# 660                                             Adverse
# 670                                       Reactant type
# 680                                             Mission
# 690                                             Joining
# 700                                           Reference
# 710                                           Alignment
# 720                                         Inaccurable
# 730                                             Country
# 740                                             Barrier
# 750                                      Geometric form
# 751                                            Material
# 760                                               Signs
# 762                                           Clergyman
# 770                                           Clamp cap
# 780                                                Ally
# 790                                         Convergence
# 800                                        Conservative
# 801                                       Conscientious
# 810                                            Firefent
# 820                                             Cathnan
# 830                                           Sincerity
# 831                                            Heritage
# 840                                             Dilemma
# 850                                                 Ily
# 860                                           Hostility
# 870                                           Hostility
# 880                                                Grid
# 890                                          Eugatology
# 900                                         Girlfriends
# 910                                        Draft emblem
# 920                                               Alarm
# 930                                              Gamble
# 936   'Translator' object has no attribute 'raise_Ex...
# 940                                            Medicine
# 945   'Translator' object has no attribute 'raise_Ex...
# 950                                               Civil
# 960                                               Honor
# 970                                               Glory
# 976   'Translator' object has no attribute 'raise_Ex...
# 980   'Translator' object has no attribute 'raise_Ex...
# 981                                            Evidence
# 990                                          Atmosphere
# 1000  'Translator' object has no attribute 'raise_Ex...
# 1001                                          Gratitude
# 1010                                               Coin
# 1011                                               Coal
# 1018  'Translator' object has no attribute 'raise_Ex...
# 1020                                             Dosage
# 1030                                               Plow
# 1040                                       Civilization
# 1050                                              Night
# 1060                                          Nightmare
# 1070                                            Rupture
# 1073  'Translator' object has no attribute 'raise_Ex...
# 1080                                          Captivity
# 1082                                        Captulation
# 1100                                           Epiphyse
# 1110                                            Welfare
# 1120                                        Girlfriends
# 1122                                      Love adoption
# 1130                                           Coashing
# 1140                                              Alarm
# 1150                                               Lack
# 1160                                            Catfish
# 1167  'Translator' object has no attribute 'raise_Ex...
# 1170                                         Eyewitness
# 1180                                   Hollow spleeming
# 1182                                        Hollow hose
# 1186  'Translator' object has no attribute 'raise_Ex...
# 1190                                       Diatericidal
# 1193  'Translator' object has no attribute 'raise_Ex...
# 1200                                            Thought
# 1201  'Translator' object has no attribute 'raise_Ex...
# 1210  'Translator' object has no attribute 'raise_Ex...
# 1211                                    Dreaming misery
# 1220                                           Occasion
# 1221  'Translator' object has no attribute 'raise_Ex...
# 1230                                           Joinness
# 1234  'Translator' object has no attribute 'raise_Ex...
# 1240  'Translator' object has no attribute 'raise_Ex...
# 1241                                          Heartburn
# 1250                                           Ligament
# 1251  'Translator' object has no attribute 'raise_Ex...
# 1260                                           Erythema
# 1265  'Translator' object has no attribute 'raise_Ex...
# 1270                                               Mark
# 1280                                          Agamation
# 1290  'Translator' object has no attribute 'raise_Ex...
# 1291                                          Heartburn
# 1300                                            Scholar
# 1310                                Bete sophistication
# 1320                                        Medium type
# 1321                                             Medium
# 1324  'Translator' object has no attribute 'raise_Ex...

# %%
# Step 6: Save the updated DataFrame to a new CSV file
df.to_csv('Thirukural_EnglishMeaning_Updated.csv', index=False, encoding='utf-8-sig')

# %%
# Step 7: Push this to Hugging Face Dataset repo 
# Clean your csv file prior to uploading

# %%
# Open the CSV file
input_file = "Thirukural_EnglishMeaning_Updated.csv"  
output_file = "cleaned_file.csv"  # Replace with the desired output file name

with open(input_file, "r", encoding="utf-8") as infile, open(output_file, "w", encoding="utf-8") as outfile:
    for line in infile:
        # Remove the starting and trailing quotes from each line
        cleaned_line = line.lstrip('"').rstrip('\n')  # Only removes quotes from the start
        outfile.write(cleaned_line + '\n')

print("Quotes removed from the beginning of each line. Saved to", output_file)
# Out:
# Quotes removed from the beginning of each line. Saved to cleaned_file.csv

# %%
import csv

# Input and output file paths
input_file = "cleaned_file.csv"  # Replace with your actual file name
output_file = "d_cleaned_file.csv"

# Open the input file and clean the data
with open(input_file, "r", encoding="utf-8") as infile, open(output_file, "w", encoding="utf-8", newline="") as outfile:
    reader = csv.reader(infile)
    writer = csv.writer(outfile)

    for row in reader:
        # Ensure there are at least 4 columns
        if len(row) > 4:
            # Combine all columns after the 3rd into the 4th column
            row = row[:3] + [",".join(row[3:])]
        elif len(row) < 4:
            # Pad with empty strings if fewer than 4 columns
            row += [""] * (4 - len(row))
        
        writer.writerow(row)

print(f"Cleaned file saved to: {output_file}")
# Out:
# Cleaned file saved to: d_cleaned_file.csv
